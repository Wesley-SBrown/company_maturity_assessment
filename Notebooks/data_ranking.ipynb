# %% [markdown]
# # Notebook for ranking Investors and Companies

# %%
import pandas as pd
import sys
import os
from sklearn.preprocessing import MinMaxScaler

# %%
clean_company = pd.read_csv('../data/cleaned/preprocessed_company_profile.csv')

# %%
clean_deals = pd.read_csv('../data/cleaned/preprocessed_deals.csv')

# %%
clean_investors = pd.read_csv('../data/cleaned/preprocessed_investors.csv')

# %%
# Get the absolute path of the scripts folder
scripts_path = os.path.abspath('../scripts')

# Add the scripts folder to the sys.path
sys.path.append(scripts_path)

# %%
company_and_deals = pd.read_csv('../data/cleaned/company_and_deals.csv')

# %%
from rank_investors import type_rank, exit_multiple
type_rank(clean_investors)
clean_investors.head()
exit_multiple(clean_investors)

# %%
clean_investors[clean_investors['Exit Multiple'] > 1].describe()
# Out:
#         Unnamed: 0  # of Investment Professionals  Year Founded           AUM  \
# count   159.000000                     159.000000    159.000000    159.000000
# mean   3032.905660                       1.308176   1989.742138    385.914717
# std    1621.781732                       2.659946     42.288523   2225.651788
# min      69.000000                       0.000000   1801.000000      0.000000
# 25%    1698.500000                       0.000000   1971.000000      0.000000
# 50%    2797.000000                       0.000000   2001.000000      0.000000
# 75%    4489.000000                       2.000000   2026.000000      0.000000
# max    5915.000000                      21.000000   2026.000000  20269.750000
#
#        Total Investments  Total Exits         Age  Investor Type Rank  \
# count         159.000000   159.000000  159.000000          159.000000
# mean            8.515723    11.264151   35.257862            6.226415
# ...

# %%
from rank_investors import quartile_ranking, investor_age_score
quartile_ranking(clean_investors)
investor_age_score(clean_investors)

# %%
from rank_investors import weighted_rank
weighted_rank(clean_investors)

# %%
clean_investors.sort_values(by='Weighted Investor Score', ascending=False)
# Out:
#       Unnamed: 0 Investor ID                          Investors  \
# 93            93    11215-09                          3i Group
# 39            39    10150-21          Fortress Investment Group
# 23            23    11105-47              Adams Street Partners
# 77            77    11105-11                              Actis
# 140          140    10015-12               Advent International
# ...          ...         ...                                ...
# 3579        3579   156669-85  Lois E. Hopkins Irrevocable Trust
# 5524        5524   481374-82      Triple Point Asset Management
# 3975        3975   148125-07                          NavPart I
# 1406        1406   156670-21                Barone Family Trust
# 5886        5886   157377-97          Wright Family Partnership
#
#                      Investor Legal Name  \
# 93                          3i Group plc
# 39        Fortress Investment Group, LLC
# 23            Adams Street Partners, LLC
# ...

# %%
clean_investors.describe()
# Out:
#         Unnamed: 0  # of Investment Professionals  Year Founded           AUM  \
# count  5972.000000                    5972.000000   5972.000000  5.972000e+03
# mean   2985.500000                      42.531815   1997.135800  1.916290e+04
# std    1724.112235                    2536.545895     31.596234  2.803171e+05
# min       0.000000                       0.000000   1801.000000  0.000000e+00
# 25%    1492.750000                       0.000000   1991.000000  0.000000e+00
# 50%    2985.500000                       3.000000   2003.000000  0.000000e+00
# 75%    4478.250000                       6.000000   2015.000000  1.000000e+02
# max    5971.000000                  196000.000000   2026.000000  1.160000e+07
#
#        Total Investments  Total Exits          Age  Investor Type Rank  \
# count         5972.00000  5972.000000  5972.000000         5972.000000
# mean           120.34779    42.350804    27.864200            5.950770
# ...

# %%
clean_investors.to_csv('../data/ranked/ranked_investors.csv')

# %%
clean_company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2123 entries, 0 to 2122
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2123 non-null   int64
#  1   Company ID                2123 non-null   object
#  2   Companies                 2123 non-null   object
#  3   Revenue                   2123 non-null   float64
#  4   Business Status           2123 non-null   object
#  5   Revenue Growth %          2123 non-null   float64
#  6   Last Financing Size       2123 non-null   float64
#  7   Website                   2123 non-null   object
#  8   LinkedIn URL              2123 non-null   object
#  9   Last Financing Valuation  2123 non-null   float64
#  10  Total Patent Documents    2123 non-null   float64
#  11  Active Patent Documents   2123 non-null   float64
#  12  Acquirers                 2123 non-null   object
# ...

# %%
clean_company['Business Status'].unique()
# Out:
# array(['Profitable', 'Generating Revenue/Not Profitable',
#        'Generating Revenue', 'Bankruptcy: Admin/Reorg',
#        'Product Development', 'Unknown', 'Out of Business', 'Restart',
#        'Bankruptcy: Liquidation', 'Startup', 'Clinical Trials - Phase 2',
#        'Clinical Trials - Phase 1', 'Clinical Trials - General',
#        'Product In Beta Test', 'Stealth'], dtype=object)

# %%
from rank_company import status_rank, age_score
status_rank(clean_company)
age_score(clean_company)

# %%
clean_company
# Out:
#       Unnamed: 0 Company ID                                   Companies  \
# 0              0   10831-42                         McKesson (NYS: MCK)
# 1              1   52120-00               Tencent Holdings (HKG: 00700)
# 2              2   10612-54                      AstraZeneca (LON: AZN)
# 3              3   10592-11                               HP (NYS: HPQ)
# 4              4   10035-64                           Intel (NAS: INTC)
# ...          ...        ...                                         ...
# 2118        2142   56685-16                                     Zemblaz
# 2119        2143   51774-31  Zencoder ( Multimedia and Design Software)
# 2120        2145   54257-05                                      Zestra
# 2121        2146   14767-66                      Zonare Medical Systems
# 2122        2147  120584-17                                   Zpredicta
#
#         Revenue                    Business Status  Revenue Growth %  \
# ...

# %%
from rank_company import quartile_ranking
quartile_ranking(clean_company)

# %%
clean_company
# Out:
#       Unnamed: 0 Company ID                                   Companies  \
# 0              0   10831-42                         McKesson (NYS: MCK)
# 1              1   52120-00               Tencent Holdings (HKG: 00700)
# 2              2   10612-54                      AstraZeneca (LON: AZN)
# 3              3   10592-11                               HP (NYS: HPQ)
# 4              4   10035-64                           Intel (NAS: INTC)
# ...          ...        ...                                         ...
# 2118        2142   56685-16                                     Zemblaz
# 2119        2143   51774-31  Zencoder ( Multimedia and Design Software)
# 2120        2145   54257-05                                      Zestra
# 2121        2146   14767-66                      Zonare Medical Systems
# 2122        2147  120584-17                                   Zpredicta
#
#         Revenue                    Business Status  Revenue Growth %  \
# ...

# %%
from rank_company import weighted_company_score
weighted_company_score(clean_company)
clean_company
# Out:
#       Unnamed: 0 Company ID                                   Companies  \
# 0              0   10831-42                         McKesson (NYS: MCK)
# 1              1   52120-00               Tencent Holdings (HKG: 00700)
# 2              2   10612-54                      AstraZeneca (LON: AZN)
# 3              3   10592-11                               HP (NYS: HPQ)
# 4              4   10035-64                           Intel (NAS: INTC)
# ...          ...        ...                                         ...
# 2118        2142   56685-16                                     Zemblaz
# 2119        2143   51774-31  Zencoder ( Multimedia and Design Software)
# 2120        2145   54257-05                                      Zestra
# 2121        2146   14767-66                      Zonare Medical Systems
# 2122        2147  120584-17                                   Zpredicta
#
#         Revenue                    Business Status  Revenue Growth %  \
# ...

# %%
clean_company.sort_values(by='Company Score', ascending=False)
# Out:
#       Unnamed: 0 Company ID  \
# 44            44   12618-46
# 305          305   41941-72
# 387          387   60580-27
# 94            94   25334-56
# 242          242   40641-85
# ...          ...        ...
# 2020        2042  646489-09
# 1811        1829  535016-62
# 2014        2036  510839-65
# 2050        2072   64937-89
# 2090        2113  647400-61
#
#                                               Companies  Revenue  \
# 44                                           C. R. Bard  3875.40
# 305                                      Antares Pharma   183.46
# 387                                   Juno Therapeutics   111.87
# 94                                          Welch Allyn  1426.40
# 242                                                 K2M   280.62
# ...                                                 ...      ...
# 2020                                    Tiw Corporation     0.00
# 1811        Pointer (Software Development Applications)     0.00
# ...

# %%
clean_company.to_csv('../data/ranked/ranked_companies.csv')
